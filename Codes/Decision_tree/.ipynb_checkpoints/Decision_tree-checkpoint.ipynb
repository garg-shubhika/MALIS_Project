# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as sc
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
airplanes_df = pd.read_csv('../../data/Clean_Dataset.csv') # read our CSV file
airplanes1_df = airplanes_df#.drop(['Unnamed: 0'], axis=1) #drops the first  column (id)
airplanes_train, airplanes_test = train_test_split(airplanes1_df, test_size=0.2, random_state=4) # on divise les données en 2 sets
###
#airplane_train and _test sont de type <class 'pandas.core.frame.DataFrame'> (the last column is price)

# %%
class Node():
    
    def __init__(self, X, depth):
        self.name = ''
        self.X_parent = X
        self.left = None #noeud de gauche
        self.right = None #noeud de droite
        self.depth = depth
        self.column = None
        self.condition = None
        self.MSE = mean_squared_error([np.mean(self.X_parent['price'])]*len(self.X_parent['price']) , self.X_parent['price'])
    
    def separate_from_class(self,column, condition): # pour separateurs par classification
        X_gauche = self.X_parent[self.X_parent[column] == condition]
        X_droite = self.X_parent[self.X_parent[column] != condition]
        if (X_gauche.empty | X_droite.empty):
            #print("VIDE: ", column,"==", condition )
            return self.MSE
        
        size_G = len(X_gauche['price'])
        size_D = len(X_droite['price'])
        
        MSE_G = mean_squared_error([np.mean(X_gauche['price'])]*size_G , X_gauche['price'])
        MSE_D = mean_squared_error([np.mean(X_droite['price'])]*size_D , X_droite['price'])

        return ( MSE_G*size_G + MSE_D*size_D )/(size_G + size_D)
        
    def separate_from_int(self,column,condition): # pour separateurs par rapport a une valeur
        X_gauche = self.X_parent[self.X_parent[column] < float(condition)]
        X_droite = self.X_parent[self.X_parent[column] >= float(condition)]
        if (X_gauche.empty | X_droite.empty):
            #print("VIDE: ", column," < ", condition )
            return self.MSE
        
        size_G = len(X_gauche['price'])
        size_D = len(X_droite['price'])
        
        MSE_G = mean_squared_error([np.mean(X_gauche['price'])]*size_G , X_gauche['price'])
        MSE_D = mean_squared_error([np.mean(X_droite['price'])]*size_D , X_droite['price'])

        return ( MSE_G*size_G + MSE_D*size_D )/(size_G + size_D)
    
    def best_split(self):
        best_MSE = self.MSE
        best_cond = self.condition
        best_column = self.column
        for column in self.X_parent.select_dtypes(include=np.number).columns.drop(["Unnamed: 0","price"]).tolist():
            #print(column)
            for trait in np.sort(self.X_parent[column].unique())[1:]:
                MSE = self.separate_from_int(column,trait)
                if ( MSE < best_MSE):
                    best_MSE = MSE
                    best_cond = trait
                    best_column = column
                    
        for column in self.X_parent.select_dtypes(include=['object']).columns.drop(["flight"]).tolist() :
            for trait in np.sort(self.X_parent[column].unique()):
                MSE = self.separate_from_class(column,trait)
                if ( MSE < best_MSE):
                    best_MSE = MSE
                    best_cond = trait
                    best_column = column
        self.MSE = best_MSE
        self.condition = best_cond
        self.column = best_column
        
        if self.column in self.X_parent.select_dtypes(include=np.number).columns.drop(["Unnamed: 0","price"]).tolist():
            print(self.depth," : ",self.name,"\t MSE: ", MSE,"\t cond:", self.column,"<", self.condition )
        else :
            print(self.depth," : ",self.name,"\t MSE: ", MSE,"\t cond:", self.column,"==", self.condition )

# %%
class Tree():
    def __init__(self,X,max_depth):
        self.leaves = []
        self.root = Node(X,0)
        self.root.name += 'root '
        self.max_depth = max_depth
        
    def branch(self,noeud):
        noeud.best_split()
        if noeud.column in noeud.X_parent.select_dtypes(include=np.number).columns.drop(["Unnamed: 0","price"]).tolist():
            X_gauche = noeud.X_parent[noeud.X_parent[noeud.column] < float(noeud.condition)]
            X_droite = noeud.X_parent[noeud.X_parent[noeud.column] >= float(noeud.condition)]
        else :
            X_gauche = noeud.X_parent[noeud.X_parent[noeud.column] == noeud.condition]
            X_droite = noeud.X_parent[noeud.X_parent[noeud.column] != noeud.condition]
        if noeud.depth == self.max_depth:
            noeud.left = X_gauche
            noeud.right = X_droite
            self.leaves.append(X_gauche)
            self.leaves.append(X_droite)
            print(noeud.depth + 1," : ",noeud.name+'L',"\t MSE: ", mean_squared_error([np.mean(noeud.left['price'])]*len(noeud.left['price']) , noeud.left['price']),"\t leaf: ", np.mean(noeud.left['price']))
            print(noeud.depth + 1," : ",noeud.name+'R',"\t MSE: ", mean_squared_error([np.mean(noeud.right['price'])]*len(noeud.right['price']) , noeud.right['price']),"\t leaf: ", np.mean(noeud.right['price']))
        else :
            noeud.left = Node(X_gauche , noeud.depth + 1)
            noeud.right = Node(X_droite , noeud.depth + 1)
            noeud.left.name = noeud.name + 'L '
            noeud.right.name = noeud.name + 'R '
            self.branch(noeud.left)
            self.branch(noeud.right)
        return
    
    def grow(self):
        self.branch(self.root)
        
    def classify(self):
        return

# %%
arbre = Tree(airplanes_df,6)
arbre.grow()
# Out:
# 0  :  root  	 MSE:  62037785.990201846 	 cond: class == Business
# 1  :  root L  	 MSE:  168201322.14790034 	 cond: duration < 4.58
# 2  :  root L L  	 MSE:  46654081.58247605 	 cond: duration < 2.08
# 3  :  root L L L  	 MSE:  12314165.6446174 	 cond: duration < 1.67
# 4  :  root L L L L  	 MSE:  6404598.255673037 	 cond: duration < 1.42
# 5  :  root L L L L L  	 MSE:  7370833.885236294 	 cond: source_city == Mumbai
# 6  :  root L L L L L L  	 MSE:  159183.35999999996 	 cond: days_left < 4
# 7  :  root L L L L L L L 	 MSE:  0.0 	 leaf:  19228.0
# 7  :  root L L L L L L R 	 MSE:  0.0 	 leaf:  17548.0
# 6  :  root L L L L L R  	 MSE:  4747804.332408511 	 cond: destination_city == Mumbai
# 7  :  root L L L L L R L 	 MSE:  0.0 	 leaf:  17738.0
# 7  :  root L L L L L R R 	 MSE:  1242649.5717770688 	 leaf:  12499.643835616438
# 5  :  root L L L L R  	 MSE:  2642324.3409225573 	 cond: source_city == Bangalore
# 6  :  root L L L L R L  	 MSE:  1744639.555555556 	 cond: days_left < 5
# 7  :  root L L L L R L L 	 MSE:  1006307.5555555555 	 leaf:  25053.333333333332
# 7  :  root L L L L R L R 	 MSE:  708931.1288888891 	 leaf:  20886.933333333334
# 6  :  root L L L L R R  	 MSE:  1385942.7183609451 	 cond: days_left < 5
# 7  :  root L L L L R R L 	 MSE:  4893906.576388889 	 leaf:  20525.083333333332
# 7  :  root L L L L R R R 	 MSE:  956416.0645717456 	 leaf:  17843.12027491409
# 4  :  root L L L R  	 MSE:  8680507.34205915 	 cond: duration < 2.0
# 5  :  root L L L R L  	 MSE:  4765743.368830586 	 cond: days_left < 5
# 6  :  root L L L R L L  	 MSE:  28907647.575279415 	 cond: airline == Air_India
# 7  :  root L L L R L L L 	 MSE:  18544907.58222222 	 leaf:  23162.866666666665
# 7  :  root L L L R L L R 	 MSE:  28371541.993055556 	 leaf:  27432.916666666668
# 6  :  root L L L R L R  	 MSE:  2810915.6468624775 	 cond: source_city == Hyderabad
# 7  :  root L L L R L R L 	 MSE:  0.0 	 leaf:  17738.0
# 7  :  root L L L R L R R 	 MSE:  2323252.431014537 	 leaf:  21348.531914893618
# 5  :  root L L L R R  	 MSE:  18540336.16134983 	 cond: departure_time == Night
# 6  :  root L L L R R L  	 MSE:  35476069.68888889 	 cond: days_left < 45
# 7  :  root L L L R R L L 	 MSE:  22728768.0 	 leaf:  37280.0
# 7  :  root L L L R R L R 	 MSE:  0.0 	 leaf:  22140.0
# 6  :  root L L L R R R  	 MSE:  4744410.316575697 	 cond: days_left < 46
# 7  :  root L L L R R R L 	 MSE:  672412.1678731063 	 leaf:  23386.955974842767
# 7  :  root L L L R R R R 	 MSE:  32618560.09876544 	 leaf:  26388.88888888889
# 3  :  root L L R  	 MSE:  39196985.23311695 	 cond: airline == Air_India
# 4  :  root L L R L  	 MSE:  20597026.446767733 	 cond: duration < 2.5
# 5  :  root L L R L L  	 MSE:  7086439.5453222655 	 cond: destination_city == Kolkata
# 6  :  root L L R L L L  	 MSE:  10132738.784738913 	 cond: source_city == Hyderabad
# 7  :  root L L R L L L L 	 MSE:  1252222.2222222222 	 leaf:  20233.333333333332
# 7  :  root L L R L L L R 	 MSE:  159319.73416197754 	 leaf:  28003.767195767196
# 6  :  root L L R L L R  	 MSE:  4432971.08311777 	 cond: days_left < 4
# 7  :  root L L R L L R L 	 MSE:  1478974.5351239669 	 leaf:  26045.68181818182
# 7  :  root L L R L L R R 	 MSE:  4180840.061176927 	 leaf:  23020.72118226601
# 5  :  root L L R L R  	 MSE:  19929873.391593117 	 cond: stops == one
# 6  :  root L L R L R L  	 MSE:  18552921.740880486 	 cond: duration < 3.83
# 7  :  root L L R L R L L 	 MSE:  871829.7657617731 	 leaf:  22290.505263157895
# 7  :  root L L R L R L R 	 MSE:  8501235.518325618 	 leaf:  31133.597222222223
# 6  :  root L L R L R R  	 MSE:  15894081.565458924 	 cond: duration < 2.75
# 7  :  root L L R L R R L 	 MSE:  16624503.209232546 	 leaf:  27348.515991471217
# 7  :  root L L R L R R R 	 MSE:  10124873.920798438 	 leaf:  31150.02125
# 4  :  root L L R R  	 MSE:  41008759.397172235 	 cond: destination_city == Hyderabad
# 5  :  root L L R R L  	 MSE:  3490073.810850366 	 cond: days_left < 2
# 6  :  root L L R R L L  	 MSE:  15366400.0 	 cond: duration < 2.33
# 7  :  root L L R R L L L 	 MSE:  0.0 	 leaf:  38470.0
# 7  :  root L L R R L L R 	 MSE:  0.0 	 leaf:  30630.0
# 6  :  root L L R R L R  	 MSE:  2545406.174961922 	 cond: days_left < 5
# 7  :  root L L R R L R L 	 MSE:  11509596.673469389 	 leaf:  26685.571428571428
# 7  :  root L L R R L R R 	 MSE:  1659551.0783999998 	 leaf:  24318.96
# 5  :  root L L R R R  	 MSE:  39876750.833226204 	 cond: duration < 2.17
# 6  :  root L L R R R L  	 MSE:  36097548.67711195 	 cond: destination_city == Chennai
# 7  :  root L L R R R L L 	 MSE:  482614.76651570457 	 leaf:  23991.967567567568
# 7  :  root L L R R R L R 	 MSE:  41932638.57530735 	 leaf:  29680.401913875598
# 6  :  root L L R R R R  	 MSE:  36472444.69209898 	 cond: source_city == Hyderabad
# 7  :  root L L R R R R L 	 MSE:  13089109.37169592 	 leaf:  26107.862660944207
# 7  :  root L L R R R R R 	 MSE:  34245782.89151727 	 leaf:  33567.057985757885
# 2  :  root L R  	 MSE:  113761785.1845217 	 cond: airline == Air_India
# 3  :  root L R L  	 MSE:  61014449.04515845 	 cond: source_city == Delhi
# 4  :  root L R L L  	 MSE:  52946875.711801045 	 cond: arrival_time == Afternoon
# 5  :  root L R L L L  	 MSE:  61150204.520271644 	 cond: destination_city == Kolkata
# 6  :  root L R L L L L  	 MSE:  72596380.89218867 	 cond: stops == one
# 7  :  root L R L L L L L 	 MSE:  63477412.578575276 	 leaf:  46117.475155279506
# 7  :  root L R L L L L R 	 MSE:  0.0 	 leaf:  27976.0
# 6  :  root L R L L L R  	 MSE:  29725884.769692894 	 cond: departure_time == Morning
# 7  :  root L R L L L R L 	 MSE:  18631015.951985225 	 leaf:  41827.63157894737
# 7  :  root L R L L L R R 	 MSE:  22474256.419486362 	 leaf:  35667.91975308642
# 5  :  root L R L L R  	 MSE:  47274019.447618425 	 cond: destination_city == Hyderabad
# 6  :  root L R L L R L  	 MSE:  13852279.171781078 	 cond: departure_time == Night
# 7  :  root L R L L R L L 	 MSE:  4312887.818181818 	 leaf:  46251.5
# 7  :  root L R L L R L R 	 MSE:  13230787.728105688 	 leaf:  42186.15789473684
# 6  :  root L R L L R R  	 MSE:  50288456.8258432 	 cond: destination_city == Bangalore
# 7  :  root L R L L R R L 	 MSE:  27146199.211940233 	 leaf:  43943.65937859609
# 7  :  root L R L L R R R 	 MSE:  52737448.80394806 	 leaf:  48050.66113537118
# 4  :  root L R L R  	 MSE:  58264195.84732302 	 cond: destination_city == Delhi
# 5  :  root L R L R L  	 MSE:  57401758.03651903 	 cond: source_city == Kolkata
# 6  :  root L R L R L L  	 MSE:  56138512.396738894 	 cond: departure_time == Night
# 7  :  root L R L R L L L 	 MSE:  29296534.514034916 	 leaf:  55633.00704225352
# 7  :  root L R L R L L R 	 MSE:  53245740.92708189 	 leaf:  48399.753607103215
# 6  :  root L R L R L R  	 MSE:  52251621.46641756 	 cond: days_left < 4
# 7  :  root L R L R L R L 	 MSE:  50882776.93127992 	 leaf:  51168.10322580645
# 7  :  root L R L R L R R 	 MSE:  50255144.61312804 	 leaf:  44016.542240215924
# 5  :  root L R L R R  	 MSE:  49573285.994593665 	 cond: destination_city == Bangalore
# 6  :  root L R L R R L  	 MSE:  52516634.970981635 	 cond: duration < 6.25
# 7  :  root L R L R R L L 	 MSE:  22615710.678399995 	 leaf:  39778.96
# 7  :  root L R L R R L R 	 MSE:  49555186.00401731 	 leaf:  55301.38248716486
# 6  :  root L R L R R R  	 MSE:  46001751.56082585 	 cond: source_city == Bangalore
# 7  :  root L R L R R R L 	 MSE:  55080299.8178138 	 leaf:  54540.29911699779
# 7  :  root L R L R R R R 	 MSE:  38500494.688783586 	 leaf:  50139.154234046255
# 3  :  root L R R  	 MSE:  118011869.52713923 	 cond: days_left < 6
# 4  :  root L R R L  	 MSE:  204206194.0951204 	 cond: days_left < 4
# 5  :  root L R R L L  	 MSE:  188410668.5793807 	 cond: destination_city == Hyderabad
# 6  :  root L R R L L L  	 MSE:  139278985.88499057 	 cond: stops == one
# 7  :  root L R R L L L L 	 MSE:  110819926.68099363 	 leaf:  64353.53051643192
# 7  :  root L R R L L L R 	 MSE:  216464701.1487889 	 leaf:  81722.70588235294
# 6  :  root L R R L L R  	 MSE:  189204470.7873677 	 cond: source_city == Kolkata
# 7  :  root L R R L L R L 	 MSE:  148843633.76468495 	 leaf:  81359.09433962264
# 7  :  root L R R L L R R 	 MSE:  185621615.6711832 	 leaf:  72145.37773722627
# 5  :  root L R R L R  	 MSE:  188277647.1001706 	 cond: destination_city == Hyderabad
# 6  :  root L R R L R L  	 MSE:  143246118.85946748 	 cond: source_city == Mumbai
# 7  :  root L R R L R L L 	 MSE:  66086372.4375 	 leaf:  62781.25
# 7  :  root L R R L R L R 	 MSE:  156314377.274375 	 leaf:  56172.275
# 6  :  root L R R L R R  	 MSE:  188782648.626226 	 cond: duration < 17.92
# 7  :  root L R R L R R L 	 MSE:  190828899.68833858 	 leaf:  66266.11057304278
# 7  :  root L R R L R R R 	 MSE:  164579654.38164127 	 leaf:  61058.5442043222
# 4  :  root L R R R  	 MSE:  106245528.23722963 	 cond: stops == one
# 5  :  root L R R R L  	 MSE:  103183128.20996763 	 cond: destination_city == Kolkata
# 6  :  root L R R R L L  	 MSE:  70987632.44216193 	 cond: source_city == Delhi
# 7  :  root L R R R L L L 	 MSE:  42377513.46969964 	 leaf:  65678.43798177996
# 7  :  root L R R R L L R 	 MSE:  70919764.95334962 	 leaf:  59767.55936637117
# 6  :  root L R R R L R  	 MSE:  106181559.04784018 	 cond: destination_city == Mumbai
# 7  :  root L R R R L R L 	 MSE:  115455638.05371144 	 leaf:  60529.835222319096
# 7  :  root L R R R L R R 	 MSE:  97535933.26635273 	 leaf:  55175.1429840405
# 5  :  root L R R R R  	 MSE:  87086339.20499906 	 cond: source_city == Delhi
# 6  :  root L R R R R L  	 MSE:  83673176.57655114 	 cond: destination_city == Chennai
# 7  :  root L R R R R L L 	 MSE:  66419851.91450361 	 leaf:  74103.8187134503
# 7  :  root L R R R R L R 	 MSE:  83877662.87848462 	 leaf:  79917.30459770115
# 6  :  root L R R R R R  	 MSE:  54481038.03161411 	 cond: source_city == Mumbai
# 7  :  root L R R R R R L 	 MSE:  40092424.502664074 	 leaf:  72889.59296482411
# 7  :  root L R R R R R R 	 MSE:  24215985.398687713 	 leaf:  63490.87634408602
# 1  :  root R  	 MSE:  14013870.567371003 	 cond: days_left < 16
# 2  :  root R L  	 MSE:  18137218.041461844 	 cond: duration < 4.5
# 3  :  root R L L  	 MSE:  5398349.408244761 	 cond: duration < 2.58
# 4  :  root R L L L  	 MSE:  3078511.590505318 	 cond: days_left < 4
# 5  :  root R L L L L  	 MSE:  8435782.965800956 	 cond: airline == Indigo
# 6  :  root R L L L L L  	 MSE:  10541508.055475837 	 cond: source_city == Delhi
# 7  :  root R L L L L L L 	 MSE:  3179517.1875 	 leaf:  6903.75
# 7  :  root R L L L L L R 	 MSE:  11393385.919885203 	 leaf:  8833.289285714285
# 6  :  root R L L L L R  	 MSE:  5580770.681388637 	 cond: duration < 1.75
# 7  :  root R L L L L R L 	 MSE:  4198519.440040479 	 leaf:  5654.675324675325
# 7  :  root R L L L L R R 	 MSE:  5282913.172850416 	 leaf:  7441.484949832776
# 5  :  root R L L L R  	 MSE:  1729590.1749399747 	 cond: duration < 1.67
# 6  :  root R L L L R L  	 MSE:  506919.4382208038 	 cond: duration < 1.17
# 7  :  root R L L L R L L 	 MSE:  340822.9265139525 	 leaf:  3898.4040816326533
# 7  :  root R L L L R L R 	 MSE:  460488.079846729 	 leaf:  4550.113272311213
# 6  :  root R L L L R R  	 MSE:  1462962.5290575859 	 cond: days_left < 15
# 7  :  root R L L L R R L 	 MSE:  1022761.5051950347 	 leaf:  6219.915767386091
# 7  :  root R L L L R R R 	 MSE:  3177443.7637332818 	 leaf:  4579.146892655367
# 4  :  root R L L R  	 MSE:  7238941.2720685415 	 cond: days_left < 4
# 5  :  root R L L R L  	 MSE:  14277264.566069344 	 cond: duration < 4.0
# 6  :  root R L L R L L  	 MSE:  12804285.181224491 	 cond: source_city == Chennai
# 7  :  root R L L R L L L 	 MSE:  15745350.395061728 	 leaf:  12527.222222222223
# 7  :  root R L L R L L R 	 MSE:  11504485.419733051 	 leaf:  9468.025477707006
# 6  :  root R L L R L R  	 MSE:  18003533.716066483 	 cond: days_left < 2
# 7  :  root R L L R L R L 	 MSE:  14273009.984375 	 leaf:  14466.375
# 7  :  root R L L R L R R 	 MSE:  16435173.723333333 	 leaf:  10977.1
# 5  :  root R L L R R  	 MSE:  5097407.614152849 	 cond: days_left < 11
# 6  :  root R L L R R L  	 MSE:  5955779.504378111 	 cond: destination_city == Mumbai
# 7  :  root R L L R R L L 	 MSE:  6222486.695225959 	 leaf:  8984.673267326732
# 7  :  root R L L R R L R 	 MSE:  5681408.040697646 	 leaf:  7720.994181213632
# 6  :  root R L L R R R  	 MSE:  3651653.8939166316 	 cond: days_left < 15
# 7  :  root R L L R R R L 	 MSE:  2918240.2800824745 	 leaf:  7225.790496760259
# 7  :  root R L L R R R R 	 MSE:  5873502.145477592 	 leaf:  6310.548936170213
# 3  :  root R L R  	 MSE:  17157171.687832467 	 cond: days_left < 4
# 4  :  root R L R L  	 MSE:  26694706.138464812 	 cond: airline == Vistara
# 5  :  root R L R L L  	 MSE:  20150111.595359094 	 cond: stops == one
# 6  :  root R L R L L L  	 MSE:  19537193.49044603 	 cond: source_city == Mumbai
# 7  :  root R L R L L L L 	 MSE:  14080556.033650832 	 leaf:  14276.33849557522
# 7  :  root R L R L L L R 	 MSE:  19792866.031237945 	 leaf:  16745.996527777777
# 6  :  root R L R L L R  	 MSE:  12318854.779160997 	 cond: duration < 23.25
# 7  :  root R L R L L R L 	 MSE:  15185060.325093895 	 leaf:  21297.364485981307
# 7  :  root R L R L L R R 	 MSE:  5818483.943821283 	 leaf:  18667.912621359224
# 5  :  root R L R L R  	 MSE:  27689888.50829332 	 cond: airline == Air_India
# 6  :  root R L R L R L  	 MSE:  25758026.179858238 	 cond: source_city == Chennai
# 7  :  root R L R L R L L 	 MSE:  32499131.841078334 	 leaf:  19916.466019417476
# 7  :  root R L R L R L R 	 MSE:  21368475.23883306 	 leaf:  14280.025594149909
# 6  :  root R L R L R R  	 MSE:  27466763.897570282 	 cond: airline == Indigo
# 7  :  root R L R L R R L 	 MSE:  22236253.697121546 	 leaf:  13837.869453924915
# 7  :  root R L R L R R R 	 MSE:  31600353.269715924 	 leaf:  11522.881796690308
# 4  :  root R L R R  	 MSE:  13633618.83582452 	 cond: airline == Vistara
# 5  :  root R L R R L  	 MSE:  8746769.459130904 	 cond: stops == one
# 6  :  root R L R R L L  	 MSE:  7362496.854497131 	 cond: days_left < 11
# 7  :  root R L R R L L L 	 MSE:  7844827.462423453 	 leaf:  12382.828217881839
# 7  :  root R L R R L L R 	 MSE:  5772240.413573946 	 leaf:  11105.185142669729
# 6  :  root R L R R L R  	 MSE:  10113207.316031752 	 cond: duration < 11.67
# 7  :  root R L R R L R L 	 MSE:  10307649.401358604 	 leaf:  17778.279452054794
# 7  :  root R L R R L R R 	 MSE:  8079204.111524644 	 leaf:  15549.67924528302
# 5  :  root R L R R R  	 MSE:  14711471.715481116 	 cond: airline == Air_India
# 6  :  root R L R R R L  	 MSE:  10752235.785344865 	 cond: source_city == Kolkata
# 7  :  root R L R R R L L 	 MSE:  6830448.605456092 	 leaf:  13396.109154929578
# 7  :  root R L R R R L R 	 MSE:  11136428.197325943 	 leaf:  11884.205243614268
# 6  :  root R L R R R R  	 MSE:  11314855.008861234 	 cond: days_left < 11
# 7  :  root R L R R R R L 	 MSE:  14007156.811813928 	 leaf:  9128.819220334142
# 7  :  root R L R R R R R 	 MSE:  7526172.071994872 	 leaf:  7472.408190051187
# 2  :  root R R  	 MSE:  4757163.532141579 	 cond: duration < 4.25
# 3  :  root R R L  	 MSE:  1539121.947815206 	 cond: duration < 2.42
# 4  :  root R R L L  	 MSE:  832103.1591107862 	 cond: duration < 1.42
# 5  :  root R R L L L  	 MSE:  199944.81626555166 	 cond: source_city == Mumbai
# 6  :  root R R L L L L  	 MSE:  94471.33669068996 	 cond: airline == Air_India
# 7  :  root R R L L L L L 	 MSE:  7776.0 	 leaf:  2138.0
# 7  :  root R R L L L L R 	 MSE:  2062.019728841043 	 leaf:  2907.979865771812
# 6  :  root R R L L L R  	 MSE:  137178.01573468777 	 cond: source_city == Chennai
# 7  :  root R R L L L R L 	 MSE:  144692.35763694954 	 leaf:  1579.6571428571428
# 7  :  root R R L L L R R 	 MSE:  117310.67066833081 	 leaf:  1828.6562322140012
# 5  :  root R R L L R  	 MSE:  805405.5569660715 	 cond: destination_city == Kolkata
# 6  :  root R R L L R L  	 MSE:  956925.2276229131 	 cond: airline == Air_India
# 7  :  root R R L L R L L 	 MSE:  1050676.3315458507 	 leaf:  2875.3664596273293
# 7  :  root R R L L R L R 	 MSE:  833566.1924142063 	 leaf:  3815.7899382171227
# 6  :  root R R L L R R  	 MSE:  656976.6457692363 	 cond: source_city == Kolkata
# 7  :  root R R L L R R L 	 MSE:  2323515.4514406994 	 leaf:  3704.423076923077
# 7  :  root R R L L R R R 	 MSE:  467515.3504938917 	 leaf:  2597.5864009906563
# 4  :  root R R L R  	 MSE:  1473855.9067376324 	 cond: destination_city == Chennai
# 5  :  root R R L R L  	 MSE:  2044595.5044419426 	 cond: source_city == Kolkata
# 6  :  root R R L R L L  	 MSE:  1569610.1107600417 	 cond: days_left < 31
# 7  :  root R R L R L L L 	 MSE:  399328.96277006174 	 leaf:  5443.402777777777
# 7  :  root R R L R L L R 	 MSE:  1038097.21 	 leaf:  3614.3
# 6  :  root R R L R L R  	 MSE:  1733439.2227662818 	 cond: days_left < 18
# 7  :  root R R L R L R L 	 MSE:  9215035.079395087 	 leaf:  4801.086956521739
# 7  :  root R R L R L R R 	 MSE:  996160.0034673469 	 leaf:  2805.2157142857145
# 5  :  root R R L R R  	 MSE:  1326077.8440628515 	 cond: source_city == Chennai
# 6  :  root R R L R R L  	 MSE:  2644134.7846757476 	 cond: days_left < 25
# 7  :  root R R L R R L L 	 MSE:  2761010.1902540107 	 leaf:  3979.6281588447655
# 7  :  root R R L R R L R 	 MSE:  2372535.001414427 	 leaf:  3084.0
# 6  :  root R R L R R R  	 MSE:  1042758.8369721536 	 cond: airline == Air_India
# 7  :  root R R L R R R L 	 MSE:  1265235.780866367 	 leaf:  3632.756097560976
# 7  :  root R R L R R R R 	 MSE:  954285.1156811093 	 leaf:  4270.684515688949
# 3  :  root R R R  	 MSE:  4517755.676564674 	 cond: airline == AirAsia
# 4  :  root R R R L  	 MSE:  2202633.3800550383 	 cond: days_left < 18
# 5  :  root R R R L L  	 MSE:  8444036.782262813 	 cond: destination_city == Bangalore
# 6  :  root R R R L L L  	 MSE:  12511017.793799875 	 cond: source_city == Delhi
# 7  :  root R R R L L L L 	 MSE:  16905068.860833332 	 leaf:  7380.65
# 7  :  root R R R L L L R 	 MSE:  4468532.698075267 	 leaf:  4718.254237288135
# 6  :  root R R R L L R  	 MSE:  6871530.819594968 	 cond: duration < 13.33
# 7  :  root R R R L L R L 	 MSE:  5135577.454394464 	 leaf:  3906.7176470588233
# 7  :  root R R R L L R R 	 MSE:  12427291.147647128 	 leaf:  5608.94623655914
# 5  :  root R R R L R  	 MSE:  1672702.6776737212 	 cond: source_city == Kolkata
# 6  :  root R R R L R L  	 MSE:  835401.7563765239 	 cond: destination_city == Delhi
# 7  :  root R R R L R L L 	 MSE:  1082612.19766358 	 leaf:  3285.9942418426103
# 7  :  root R R R L R L R 	 MSE:  582937.0002888889 	 leaf:  3978.3933333333334
# 6  :  root R R R L R R  	 MSE:  1726729.958091322 	 cond: destination_city == Bangalore
# 7  :  root R R R L R R L 	 MSE:  2140483.062729407 	 leaf:  3482.220512820513
# 7  :  root R R R L R R R 	 MSE:  1573234.1693025061 	 leaf:  2824.2432902945015
# 4  :  root R R R R  	 MSE:  4207143.048874283 	 cond: airline == Indigo
# 5  :  root R R R R L  	 MSE:  3873693.846234156 	 cond: days_left < 31
# 6  :  root R R R R L L  	 MSE:  3516949.000780639 	 cond: source_city == Kolkata
# 7  :  root R R R R L L L 	 MSE:  2055380.46028084 	 leaf:  6200.331573389652
# 7  :  root R R R R L L R 	 MSE:  3590978.220773059 	 leaf:  5003.701029617389
# 6  :  root R R R R L R  	 MSE:  3284579.639757141 	 cond: days_left < 39
# 7  :  root R R R R L R L 	 MSE:  3933269.7350125774 	 leaf:  4364.403371001724
# 7  :  root R R R R L R R 	 MSE:  2468382.04032844 	 leaf:  3445.769462719298
# 5  :  root R R R R R  	 MSE:  3852891.633251529 	 cond: stops == one
# 6  :  root R R R R R L  	 MSE:  3287969.772442367 	 cond: source_city == Kolkata
# 7  :  root R R R R R L L 	 MSE:  3053315.4769782266 	 leaf:  6631.796275395034
# 7  :  root R R R R R L R 	 MSE:  3181268.3583611785 	 leaf:  5652.042960926762
# 6  :  root R R R R R R  	 MSE:  6437866.4049232565 	 cond: source_city == Chennai
# 7  :  root R R R R R R L 	 MSE:  4066454.1025739694 	 leaf:  6775.603575184017
# 7  :  root R R R R R R R 	 MSE:  6390038.159038976 	 leaf:  8540.026913533116

# %%
print(np.sort([int(np.mean(leaf['price'])) for leaf in arbre.leaves]))
# Out:
# [ 1579  1828  2138  2597  2805  2824  2875  2907  3084  3285  3445  3482
#   3614  3632  3704  3815  3898  3906  3978  3979  4270  4364  4550  4579
#   4718  4801  5003  5443  5608  5652  5654  6200  6219  6310  6631  6775
#   6903  7225  7380  7441  7472  7720  8540  8833  8984  9128  9468 10977
#  11105 11522 11884 12382 12499 12527 13396 13837 14276 14280 14466 15549
#  16745 17548 17738 17738 17778 17843 18667 19228 19916 20233 20525 20886
#  21297 21348 22140 22290 23020 23162 23386 23991 24318 25053 26045 26107
#  26388 26685 27348 27432 27976 28003 29680 30630 31133 31150 33567 35667
#  37280 38470 39778 41827 42186 43943 44016 46117 46251 48050 48399 50139
#  51168 54540 55175 55301 55633 56172 59767 60529 61058 62781 63490 64353
#  65678 66266 72145 72889 74103 79917 81359 81722]

# %%
print('if' , arbre.root.right.left.right.right.left.left.column,' < ou == ',arbre.root.right.left.right.right.left.left.condition ,'then left')
# Out:
# if days_left  < ou ==  11 then left

# %%
fig = plt.figure(1)	#identifies the figure 
plt.title("feuilles de l'arbre", fontsize='10')	#title
k = 0
for leaf in arbre.leaves:
    plt.plot(list(leaf['price']), [k]*len(list(leaf['price'])))	#plot the points
    k+=1
plt.grid()	#shows a grid under the plot
plt.show()
